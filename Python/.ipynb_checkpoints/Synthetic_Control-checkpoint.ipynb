# %% [markdown]
# ## Welcome
#
# This is material for the **Synthetic Control** chapter in Scott Cunningham's book, [Causal Inference: The Mixtape.](https://mixtape.scunning.com/)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from SyntheticControlMethods import Synth

import plotnine as p

# %%
# read data
def read_data(file):
    return pd.read_stata("https://raw.github.com/scunning1975/mixtape/master/" + file)

# %%
# !pip install git+https://github.com/gnazareths/synth/tree/master.git
# Out:
# Collecting git+https://github.com/gnazareths/synth/tree/master.git
#   Cloning https://github.com/gnazareths/synth/tree/master.git to /private/var/folders/sd/qsjtdsjd5_g812vpkm3j7fj40000gn/T/pip-req-build-ippfi5sc
# ERROR: Command errored out with exit status 128: git clone -q https://github.com/gnazareths/synth/tree/master.git /private/var/folders/sd/qsjtdsjd5_g812vpkm3j7fj40000gn/T/pip-req-build-ippfi5sc Check the logs for full command output.

# %%
from mypackage import synth_tables
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-c914b6b9b994> in <module>
# ----> 1 from mypackage import synth_tables
#
# ModuleNotFoundError: No module named 'mypackage'

# %% [markdown]
# ## Prison Construction and Black Male Incarceration

# %%
texas = read_data("texas.dta")

# %%
texas.head()
# Out:
#    statefip    year  race  bmprison  wmprison   bmpop    wmpop  error  \
# 0       1.0  1985.0   2.0    6227.0    4210.0  464428  1427743    0.0
# 1       1.0  1986.0   1.0    6657.0    4423.0  465387  1434773    0.0
# 2       1.0  1987.0   1.0    7281.0    4803.0  467545  1442894    0.0
# 3       1.0  1988.0   1.0    7244.0    4605.0  468281  1445048    0.0
# 4       1.0  1989.0   1.0    8056.0    4998.0  468893  1445678    0.0
#
#       crack  alcohol  ...  perc1519  aidscapita    state  parole  probation  \
# 0  0.217438     1.90  ...  8.461768    0.679504  Alabama  2425.0      16520
# 1  0.276875     1.90  ...  8.473580    0.851692  Alabama  3038.0      21371
# 2  0.211371     1.89  ...  8.397089    1.967214  Alabama  3456.0      23406
# 3  0.559781     1.89  ...  8.280076    2.758137  Alabama  4701.0      25301
# 4  0.721824     1.87  ...  8.088959    3.845907  Alabama  5724.0      25519
#
#    capacity_rated capacity_operational  capacity_design      bmprate  \
# 0          9787.0               9787.0           9787.0  1340.789062
# 1         10374.0              10374.0          10374.0  1430.422363
# 2         11107.0              11107.0          11107.0  1557.283203
# 3         11162.0              11162.0          11162.0  1546.934448
# 4         11162.0              11662.0          11662.0  1718.089233
#
#       wmprate
# 0  294.871002
# 1  308.271759
# 2  332.872681
# 3  318.674530
# 4  345.720154
#
# [5 rows x 24 columns]

# %%
synth_tecas
# Out:
#      statefip    year  race  bmprison  wmprison   bmpop    wmpop  error  \
# 0         1.0  1985.0   2.0    6227.0    4210.0  464428  1427743    0.0
# 1         1.0  1986.0   1.0    6657.0    4423.0  465387  1434773    0.0
# 2         1.0  1987.0   1.0    7281.0    4803.0  467545  1442894    0.0
# 3         1.0  1988.0   1.0    7244.0    4605.0  468281  1445048    0.0
# 4         1.0  1989.0   1.0    8056.0    4998.0  468893  1445678    0.0
# ..        ...     ...   ...       ...       ...     ...      ...    ...
# 811      56.0  1996.0   1.0      73.0    1067.0    2159   232225    0.0
# 812      56.0  1997.0   1.0      74.0    1077.0    2102   232215    0.0
# 813      56.0  1998.0   2.0      69.0    1086.0    2210   232515    0.0
# 814      56.0  1999.0   2.0      81.0    1187.0    2232   231526    0.0
# 815      56.0  2000.0   2.0      93.0    1150.0    2182   228279    0.0
#
#         crack  alcohol  ...  perc1519  aidscapita    state  parole  probation  \
# 0    0.217438     1.90  ...  8.461768    0.679504  Alabama  2425.0      16520
# 1    0.276875     1.90  ...  8.473580    0.851692  Alabama  3038.0      21371
# 2    0.211371     1.89  ...  8.397089    1.967214  Alabama  3456.0      23406
# 3    0.559781     1.89  ...  8.280076    2.758137  Alabama  4701.0      25301
# 4    0.721824     1.87  ...  8.088959    3.845907  Alabama  5724.0      25519
# ..        ...      ...  ...       ...         ...      ...     ...        ...
# 811  0.379070     2.34  ...  8.593781    1.024240  Wyoming   364.0       3432
# 812 -0.208257     2.33  ...  8.691779    0.000000  Wyoming   422.0       3486
# 813 -0.869869     2.40  ...  8.732709    1.630035  Wyoming   448.0       3825
# 814 -0.420732     2.43  ...  8.646752    0.000000  Wyoming   458.0       3841
# 815  0.113628     2.46  ...  8.449946    1.214363  Wyoming   514.0       4115
#
#      capacity_rated capacity_operational  capacity_design      bmprate  \
# 0            9787.0               9787.0           9787.0  1340.789062
# 1           10374.0              10374.0          10374.0  1430.422363
# 2           11107.0              11107.0          11107.0  1557.283203
# 3           11162.0              11162.0          11162.0  1546.934448
# 4           11162.0              11662.0          11662.0  1718.089233
# ..              ...                  ...              ...          ...
# 811           981.0               1244.0           1035.0  3381.195068
# 812          1231.0               1243.0           1047.0  3520.456787
# 813          1231.0               1243.0           1047.0  3122.171875
# 814          1231.0               1243.0           1047.0  3629.032227
# 815          1314.0               1303.0           1251.0  4262.145020
#
#         wmprate
# 0    294.871002
# 1    308.271759
# 2    332.872681
# 3    318.674530
# 4    345.720154
# ..          ...
# 811  459.468201
# 812  463.794342
# 813  467.066650
# 814  512.685425
# 815  503.769501
#
# [816 rows x 24 columns]

# %%
synth_tecas.loc[:, cols].head()
# Out:
#    bmprison  alcohol  aidscapita      black  perc1519    year  statefip
# 0    6227.0     1.90    0.679504  25.866339  8.461768  1985.0       1.0
# 1    6657.0     1.90    0.851692  25.827267  8.473580  1986.0       1.0
# 2    7281.0     1.89    1.967214  25.777328  8.397089  1987.0       1.0
# 3    7244.0     1.89    2.758137  25.734392  8.280076  1988.0       1.0
# 4    8056.0     1.87    3.845907  25.694050  8.088959  1989.0       1.0

# %%
output = synth_tables( texas,   ## pandas dataframe
                       texas['bmprison'],     ## pandas dataframe
                       48,        ## string with the index of the treated unit
                       control_units,       ## array with indexes all control units
                       ['alcohol', 'aidscapita', 'black', 'perc1519'], ## to be clear, these are the predictors that matter, 
                                            ## in case there are extra ones.
                       np.arange(1985, 1994),   ## these are the time periods for which you are optimizing the RSS.
                                            ## you should not include anything after the treatment to ensure validity.
                       np.arange(1985, 2001)           ## years which you want to plot
                 )

# %%
data = pd.read_csv("https://raw.githubusercontent.com/OscarEngelbrektson/SyntheticControlMethods/master/examples/datasets/german_reunification.csv")

# %%
# !pip install -U scipy==1.4.1
# Out:
# Requirement already up-to-date: scipy==1.4.1 in /Users/tcaputo/opt/anaconda3/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/tcaputo/opt/anaconda3/lib/python3.8/site-packages (from scipy==1.4.1) (1.19.2)

# %%
sc = Synth(data, "gdp", "country", "year", 1990, "West Germany")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ab9ae95fabca> in <module>
# ----> 1 sc = Synth(data, "gdp", "country", "year", 1990, "West Germany")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/SyntheticControlMethods/main.py in __init__(self, dataset, outcome_var, id_var, time_var, treatment_period, treated_unit, n_optim, pen, **kwargs)
#     382
#     383         #Get synthetic Control
# --> 384         self.optimize(self.original_data.treated_outcome, self.original_data.treated_covariates,
#     385                     self.original_data.control_outcome, self.original_data.control_covariates,
#     386                     self.original_data.pairwise_difference,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/SyntheticControlMethods/inferences.py in optimize(self, treated_outcome, treated_covariates, control_outcome, control_covariates, pairwise_difference, data, placebo, pen, steps, verbose)
#      73
#      74             #Optimze
# ---> 75             res = minimize(self.total_loss, v_0,  args=(args),
#      76                             method='L-BFGS-B', bounds=bnds,
#      77                             options={'gtol': 1e-6,'disp':3, 'iprint':3})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     616     elif meth == 'slsqp':
# --> 617         return _minimize_slsqp(fun, x0, args, jac, bounds,
#     618                                constraints, callback=callback, **options)
#     619     elif meth == 'trust-constr':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304                   (1, 1): 2,
#     305                   (None, 1): 3}
# --> 306     for i in range(0, n):
#     307         l, u = bounds[i]
#     308         if l is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     Examples
#     260     --------
# --> 261     >>> from scipy.optimize import rosen_hess
#     262     >>> X = 0.1 * np.arange(4)
#     263     >>> rosen_hess(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#      93         self._update_grad()
#      94
# ---> 95         # Hessian Evaluation
#      96         if callable(hess):
#      97             self.H = hess(x0, *args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     169             self._update_grad_impl()
#     170             self.g_updated = True
# --> 171
#     172     def _update_hess(self):
#     173         if not self.H_updated:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#      89                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#      90                                            **finite_diff_options)
# ---> 91
#      92         self._update_grad_impl = update_grad
#      93         self._update_grad()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     386             if not issparse(sparsity) and len(sparsity) == 2:
#     387                 structure, groups = sparsity
# --> 388             else:
#     389                 structure = sparsity
#     390                 groups = group_columns(sparsity)
#
# ValueError: `f0` passed has more than 1 dimension.

# %%
control_units = [1, 2, 4, 5, 6] + list(range(8, 14)) + list(range(15,43)) + list(range(44, 47)) + [49, 50, 51, 53,54,55,56]

synth_tecas = texas[texas.statefip.isin(statefips)]
cols = ['bmprison', 'alcohol', 'aidscapita', 'black', 'perc1519', 'year', 'statefip']
sc = Synth(synth_tecas.loc[:, cols], 
           "bmprison", 
           'statefip',
           "year",
           1993,
           48,
          pen=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-96f88729dc88> in <module>
#       3 synth_tecas = texas[texas.statefip.isin(statefips)]
#       4 cols = ['bmprison', 'alcohol', 'aidscapita', 'black', 'perc1519', 'year', 'statefip']
# ----> 5 sc = Synth(synth_tecas.loc[:, cols],
#       6            "bmprison",
#       7            'statefip',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/SyntheticControlMethods/main.py in __init__(self, dataset, outcome_var, id_var, time_var, treatment_period, treated_unit, n_optim, pen, **kwargs)
#     382
#     383         #Get synthetic Control
# --> 384         self.optimize(self.original_data.treated_outcome, self.original_data.treated_covariates,
#     385                     self.original_data.control_outcome, self.original_data.control_covariates,
#     386                     self.original_data.pairwise_difference,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/SyntheticControlMethods/inferences.py in optimize(self, treated_outcome, treated_covariates, control_outcome, control_covariates, pairwise_difference, data, placebo, pen, steps, verbose)
#      73
#      74             #Optimze
# ---> 75             res = minimize(self.total_loss, v_0,  args=(args),
#      76                             method='L-BFGS-B', bounds=bnds,
#      77                             options={'gtol': 1e-6,'disp':3, 'iprint':3})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615         return _minimize_cobyla(fun, x0, args, constraints, **options)
#     616     elif meth == 'slsqp':
# --> 617         return _minimize_slsqp(fun, x0, args, jac, bounds,
#     618                                constraints, callback=callback, **options)
#     619     elif meth == 'trust-constr':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304                   (1, 1): 2,
#     305                   (None, 1): 3}
# --> 306     for i in range(0, n):
#     307         l, u = bounds[i]
#     308         if l is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     Examples
#     260     --------
# --> 261     >>> from scipy.optimize import rosen_hess
#     262     >>> X = 0.1 * np.arange(4)
#     263     >>> rosen_hess(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#      93         self._update_grad()
#      94
# ---> 95         # Hessian Evaluation
#      96         if callable(hess):
#      97             self.H = hess(x0, *args)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     169             self._update_grad_impl()
#     170             self.g_updated = True
# --> 171
#     172     def _update_hess(self):
#     173         if not self.H_updated:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#      89                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#      90                                            **finite_diff_options)
# ---> 91
#      92         self._update_grad_impl = update_grad
#      93         self._update_grad()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     386             if not issparse(sparsity) and len(sparsity) == 2:
#     387                 structure, groups = sparsity
# --> 388             else:
#     389                 structure = sparsity
#     390                 groups = group_columns(sparsity)
#
# ValueError: `f0` passed has more than 1 dimension.

# %%
texas <- read_data("texas.dta") %>%
  as.data.frame(.)
dataprep_out <- dataprep(
  foo = texas,
  predictors = c("poverty", "income"),
  predictors.op = "mean",
  time.predictors.prior = 1985:1993,
  special.predictors = list(
    list("bmprison", c(1988, 1990:1992), "mean"),
    list("alcohol", 1990, "mean"),
    list("aidscapita", 1990:1991, "mean"),
    list("black", 1990:1992, "mean"),
    list("perc1519", 1990, "mean")),
  dependent = "bmprison",
  unit.variable = "statefip",
  unit.names.variable = "state",
  time.variable = "year",
  treatment.identifier = 48,
  controls.identifier = c(1,2,4:6,8:13,15:42,44:47,49:51,53:56),
  time.optimize.ssr = 1985:1993,
  time.plot = 1985:2000
)
synth_out <- synth(data.prep.obj = dataprep_out)
cli::cli_h1("Path Plot")
path.plot(synth_out, dataprep_out)
cli::cli_h1("Gap Plot")
gaps.plot(synth_out, dataprep_out)
cli::cli_h1("Placebos")
placebos <- generate.placebos(dataprep_out, synth_out, Sigf.ipop = 3)
plot_placebos(placebos)
mspe.plot(placebos, discard.extreme = TRUE, mspe.limit = 1, plot.hist = TRUE)

# %% [markdown]
# #### Questions
# - In your own words, what do you think the identifying assumptions are for synthetic control to be consistent?
# - What role, if any, does parallel trends play in synthetic control?
# - Who is the unit with the largest ratio of post to pre RMSPE?
# - Compare the unit with the largest post to pre RMSPE estimated effect to the Texas effect.  How do the weights compare?  How do the size of the effects compare?  How do the ``signs`` of the effects compare?
# - Can you improve on my fit by experimenting with different combinations? Do so and report your analysis.
# - Report results from a variety of different specifications.  How robust does the prison effect appear to be?
